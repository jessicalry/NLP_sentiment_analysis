# %%
import nltk
import csv
import ssl ## workaround for my specific authorization issue
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

DATA_PATH = 'out.csv'
nltk.download('stopwords')
nltk.download('wordnet')

df = pd.read_csv(DATA_PATH)
####### FOR TESTING ONLY ###########
#df = df.head(100)

####### DROP USELESS COLUMNS  ###########
df = df.drop('review_id', axis=1)
df = df.drop('business_id', axis=1)
df = df.drop('funny', axis=1)
df = df.drop('cool', axis=1)
df = df.drop('date', axis=1)
####### LOWERCASE  ###########
df['text-lowered'] = df['text'].str.lower()
####### TOKENIZATION  ###########
df['tokenized_text'] = df['text-lowered'].apply(word_tokenize)
df = df.drop('text-lowered', axis=1)
####### STOPWORDS REMOVAL  ###########
stop = stopwords.words('english')
df['tokenized_text'] = df['tokenized_text'].apply(lambda x: [item for item in x if item not in stop])
####### STEMMING  ###########
stemmer = PorterStemmer()
df['tokenized_text'] = df['tokenized_text'].apply(lambda x: [stemmer.stem(y) for y in x])
####### Lemmatizating  ###########
lmtzr = WordNetLemmatizer()
df['tokenized_text'] = df['tokenized_text'].apply(lambda x: [lmtzr.lemmatize(y) for y in x])
######## LISTS JOIN AS SINGLE STRING ############
df['tokenized_text_string'] = [' '.join(map(str, l)) for l in df['tokenized_text']]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/diwang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/diwang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df
# Out:
#                    user_id  stars  useful  \
# 0   ak0TdVmGKo4pwqdJSTLwWw      4       3
# 1   YoVfDbnISlW0f7abNQACIg      4       1
# 2   eC5evKn1TWDyHCyQAwguUw      5       0
# 3   SFQ1jcnGguO0LYWnbbftAA      2       1
# 4   0kA0PAJ8QFMeveQWHFqz2A      4       0
# ..                     ...    ...     ...
# 95  UU0OFv3ni6e7hwIXjueZ0w      2       0
# 96  1vTcHEsdA4202XJbNoTDtQ      1       4
# 97  bUVFpVxZdnFOh2BZzCoLYw      1       2
# 98  suBpZTEXih253-0s_2GWCw      3       4
# 99  FcJw5upAp2kpkEC9yjvkXA      2       0
#
#                                                  text  \
# 0   Apparently Prides Osteria had a rough summer a...
# 1   This store is pretty good. Not as great as Wal...
# 2   I called WVM on the recommendation of a couple...
# 3   I've stayed at many Marriott and Renaissance M...
# 4   The food is always great here. The service fro...
# ..                                                ...
# 95  I used to love this place.  The food is very g...
# 96  My brother in law suggested this place, and we...
# 97  Will not be back!!! The service was just awful...
# 98  Let me start by saying this place is lucky my ...
# 99  Good may have been good if my server Megan T a...
#
#                                        tokenized_text  \
# 0   [appar, pride, osteria, rough, summer, evidenc...
# 1   [store, pretti, good, ., great, walmart, (, pr...
# 2   [call, wvm, recommend, coupl, friend, use, pas...
# 3   ['ve, stay, mani, marriott, renaiss, marriott,...
# 4   [food, alway, great, ., servic, manag, well, s...
# ..                                                ...
# 95  [use, love, place, ., food, good, ,, thank, n'...
# 96  [brother, law, suggest, place, ,, came, right,...
# 97  [back, !, !, !, servic, aw, ., use, scoutmob, ...
# 98  [let, start, say, place, lucki, girlfriend, n'...
# 99  [good, may, good, server, megan, actual, use, ...
#
#                                 tokenized_text_string
# 0   appar pride osteria rough summer evidenc almos...
# 1   store pretti good . great walmart ( prefer , m...
# 2   call wvm recommend coupl friend use past thoug...
# 3   've stay mani marriott renaiss marriott 's hug...
# 4   food alway great . servic manag well staff sup...
# ..                                                ...
# 95  use love place . food good , thank n't chang ....
# 96  brother law suggest place , came right arriv o...
# 97  back ! ! ! servic aw . use scoutmob tri act li...
# 98  let start say place lucki girlfriend n't one r...
# 99  good may good server megan actual use pad took...
#
# [100 rows x 6 columns]
